# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('amazon.csv')

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: object(16)
# memory usage: 183.3+ KB

# %%
def check_df(dataframe, head = 5):
    print('------------------shape---------------')
    print(dataframe.shape)
    print('------------------types---------------')
    print(dataframe.dtypes)
    print('------------------NAN---------------')
    print(dataframe.isnull().sum())
    print('------------------describe---------------')
    print(dataframe.describe().T)

# %%
df.isnull().mean()*100
# Out:
# product_id             0.000000
# product_name           0.000000
# category               0.000000
# discounted_price       0.000000
# actual_price           0.000000
# discount_percentage    0.000000
# rating                 0.000000
# rating_count           0.136519
# about_product          0.000000
# user_id                0.000000
# user_name              0.000000
# review_id              0.000000
# review_title           0.000000
# review_content         0.000000
# img_link               0.000000
# product_link           0.000000
# dtype: float64

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop(["about_product","review_content",'review_title','img_link','product_link','review_id','product_id','user_name','user_id' ],axis = 1)
df.head()
# Out:
#                                         product_name  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905

# %%
df['category']
# Out:
# 0       Computers&Accessories|Accessories&Peripherals|...
# 1       Computers&Accessories|Accessories&Peripherals|...
# 2       Computers&Accessories|Accessories&Peripherals|...
# 3       Computers&Accessories|Accessories&Peripherals|...
# 4       Computers&Accessories|Accessories&Peripherals|...
#                               ...
# 1460    Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...
# 1461    Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# 1462    Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# 1463    Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...
# 1464    Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# Name: category, Length: 1465, dtype: object

# %%
df['product type']=df['category'].str.split('|').str[-1]

# %%
df['category']=df['category'].str.split('|').str[0]

# %%
df.sample(5)
# Out:
#                                           product_name               category  \
# 928  Portronics Konnect L 1.2Mtr, Fast Charging 3A ...  Computers&Accessories
# 807  Portronics Ruffpad 8.5M Multicolor LCD Writing...  Computers&Accessories
# 417  Ambrane 20000mAh Power Bank with 20W Fast Char...            Electronics
# 696                HP 682 Black Original Ink Cartridge  Computers&Accessories
# 2    Sounce Fast Phone Charging Cable & Data Sync U...  Computers&Accessories
#
#     discounted_price actual_price discount_percentage rating rating_count  \
# 928             ₹154         ₹349                 56%    4.3        7,064
# 807             ₹378         ₹999                 62%    4.1        1,779
# 417           ₹1,799       ₹2,499                 28%    4.1       18,678
# 696             ₹828         ₹861                  4%    4.2        4,567
# 2               ₹199       ₹1,899                 90%    3.9        7,928
#
#             product type
# 928            USBCables
# 807       GraphicTablets
# 417           PowerBanks
# 696  InkjetInkCartridges
# 2              USBCables

# %%
df["discounted_price"] = df["discounted_price"].apply(lambda x : x.replace("₹",""))
df["actual_price"] =  df["actual_price"].apply(lambda x : x.replace("₹",""))

# %%
df["discounted_price"] = df["discounted_price"].apply(lambda x : x.replace(",","."))
df["actual_price"] =  df["actual_price"].apply(lambda x : x.replace(",","."))

# %%
df.head()
# Out:
#                                         product_name               category  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...  Computers&Accessories
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...  Computers&Accessories
# 2  Sounce Fast Phone Charging Cable & Data Sync U...  Computers&Accessories
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...  Computers&Accessories
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...  Computers&Accessories
#
#   discounted_price actual_price discount_percentage rating rating_count  \
# 0              399        1.099                 64%    4.2       24,269
# 1              199          349                 43%    4.0       43,994
# 2              199        1.899                 90%    3.9        7,928
# 3              329          699                 53%    4.2       94,363
# 4              154          399                 61%    4.2       16,905
#
#   product type
# 0    USBCables
# 1    USBCables
# 2    USBCables
# 3    USBCables
# 4    USBCables

# %%
df.head()
# Out:
#                                         product_name               category  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...  Computers&Accessories
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...  Computers&Accessories
# 2  Sounce Fast Phone Charging Cable & Data Sync U...  Computers&Accessories
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...  Computers&Accessories
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...  Computers&Accessories
#
#   discounted_price actual_price discount_percentage rating rating_count  \
# 0              399        1.099                 64%    4.2       24,269
# 1              199          349                 43%    4.0       43,994
# 2              199        1.899                 90%    3.9        7,928
# 3              329          699                 53%    4.2       94,363
# 4              154          399                 61%    4.2       16,905
#
#   product type
# 0    USBCables
# 1    USBCables
# 2    USBCables
# 3    USBCables
# 4    USBCables

# %%
df["discounted_price"] = df["discounted_price"].apply(lambda x : x.replace("₹",""))
df["actual_price"] =  df["actual_price"].apply(lambda x : x.replace("₹",""))

# %%
df["discounted_price"] = df["discounted_price"].apply(lambda x : x.replace(",","."))
df["actual_price"] =  df["actual_price"].apply(lambda x : x.replace(",","."))

# %%
df.head()
# Out:
#                                         product_name               category  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...  Computers&Accessories
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...  Computers&Accessories
# 2  Sounce Fast Phone Charging Cable & Data Sync U...  Computers&Accessories
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...  Computers&Accessories
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...  Computers&Accessories
#
#   discounted_price actual_price discount_percentage rating rating_count  \
# 0              399        1.099                 64%    4.2       24,269
# 1              199          349                 43%    4.0       43,994
# 2              199        1.899                 90%    3.9        7,928
# 3              329          699                 53%    4.2       94,363
# 4              154          399                 61%    4.2       16,905
#
#   product type
# 0    USBCables
# 1    USBCables
# 2    USBCables
# 3    USBCables
# 4    USBCables

# %%
df.sample(5)
# Out:
#                                            product_name  \
# 1445  Larrito wooden Cool Mist Humidifiers Essential...
# 1152  Lint Roller with 40 Paper Sheets, 22 x 5 cm (G...
# 1284  iBELL SM1301 3-in-1 Sandwich Maker with Detach...
# 914   MI 360° Home Security Wireless Camera 2K Pro w...
# 922   Samsung 24-inch(60.46cm) FHD Monitor, IPS, 75 ...
#
#                    category discounted_price actual_price discount_percentage  \
# 1445           Home&Kitchen              499          799                 38%
# 1152           Home&Kitchen              245          299                 18%
# 1284           Home&Kitchen            2.092        4.600                 55%
# 914             Electronics            4.499        5.999                 25%
# 922   Computers&Accessories           10.099       19.110                 47%
#
#      rating rating_count    product type
# 1445    3.6          212     Humidifiers
# 1152    4.1        1,660     LintShavers
# 1284    4.3          562  SandwichMakers
# 914     4.3       44,696     DomeCameras
# 922     4.3        2,623        Monitors

# %%
df.discounted_price = df.discounted_price.str.split(".").str.get(0) +"."+ df.discounted_price.str.split(".").str.get(1).fillna("0")

# %%
df.head()
# Out:
#                                         product_name               category  \
# 0  Wayona Nylon Braided USB to Lightning Fast Cha...  Computers&Accessories
# 1  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...  Computers&Accessories
# 2  Sounce Fast Phone Charging Cable & Data Sync U...  Computers&Accessories
# 3  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...  Computers&Accessories
# 4  Portronics Konnect L 1.2M Fast Charging 3A 8 P...  Computers&Accessories
#
#   discounted_price actual_price discount_percentage rating rating_count  \
# 0            399.0        1.099                 64%    4.2       24,269
# 1            199.0          349                 43%    4.0       43,994
# 2            199.0        1.899                 90%    3.9        7,928
# 3            329.0          699                 53%    4.2       94,363
# 4            154.0          399                 61%    4.2       16,905
#
#   product type
# 0    USBCables
# 1    USBCables
# 2    USBCables
# 3    USBCables
# 4    USBCables

# %%
df.sample(5)
# Out:
#                                            product_name  \
# 188   Karbonn 80 cm (32 inches) Millenium Bezel-Less...
# 1113  USHA Heat Convector 812 T 2000-Watt with Insta...
# 136   pTron Solero 331 3.4Amps Multifunction Fast Ch...
# 1152  Lint Roller with 40 Paper Sheets, 22 x 5 cm (G...
# 879   Sony WI-C100 Wireless Headphones with Customiz...
#
#                    category discounted_price actual_price discount_percentage  \
# 188             Electronics            8.990       18.990                 53%
# 1113           Home&Kitchen            2.199        2.990                 26%
# 136   Computers&Accessories            249.0          931                 73%
# 1152           Home&Kitchen            245.0          299                 18%
# 879             Electronics            1.599        2.790                 43%
#
#      rating rating_count      product type
# 188     3.9          350  SmartTelevisions
# 1113    3.8        1,558    HeatConvectors
# 136     3.9        1,075         USBCables
# 1152    4.1        1,660       LintShavers
# 879     3.6        2,272            In-Ear

# %%
df.discounted_price = df.discounted_price.astype(float)

# %%
df.sample(5)
# Out:
#                                           product_name               category  \
# 984  Camel Oil Pastel with Reusable Plastic Box - 5...           Home&Kitchen
# 293  Tuarso 8K HDMI 2.1 Cable 48Gbps , 1.5 Meter Hi...            Electronics
# 258  boAt Rugged V3 Braided Micro USB Cable (Pearl ...  Computers&Accessories
# 667  Zebronics ZEB-KM2100 Multimedia USB Keyboard C...  Computers&Accessories
# 651  Zebronics Zeb-Transformer-M Optical USB Gaming...  Computers&Accessories
#
#      discounted_price actual_price discount_percentage rating rating_count  \
# 984             230.0          230                  0%    4.5        9,427
# 293             599.0        1.999                 70%    4.2           47
# 258             299.0          799                 63%    4.2       94,363
# 667             329.0          399                 18%    3.6       33,735
# 651             399.0          549                 27%    4.4       18,139
#
#           product type
# 984  PaintingMaterials
# 293         HDMICables
# 258          USBCables
# 667          Keyboards
# 651         GamingMice

# %%
df.actual_price = df.actual_price.str.split(".").str.get(0) +"."+ df.actual_price.str.split(".").str.get(1).fillna("0")

# %%
df.actual_price = df.actual_price.astype(float)

# %%
df.rating = df.rating.apply(lambda x : x.replace("|", "NaN" ))

# %%
df['rating'] = df['rating'].apply(lambda x: x.replace(",", "."))

# %%
df.rating = df.rating.astype(float)

# %%
df.sample(5)
# Out:
#                                           product_name               category  \
# 584  boAt BassHeads 100 in-Ear Wired Headphones wit...            Electronics
# 459  Spigen EZ Fit Tempered Glass Screen Protector ...            Electronics
# 462  boAt Newly Launched Wave Electra with 1.81" HD...            Electronics
# 736  TP-link N300 WiFi Wireless Router TL-WR845N | ...  Computers&Accessories
# 397  Samsung EVO Plus 128GB microSDXC UHS-I U3 130M...            Electronics
#
#      discounted_price  actual_price discount_percentage  rating rating_count  \
# 584           365.000       999.000                 63%     4.1     3,63,711
# 459           999.000         2.899                 66%     4.7        7,779
# 462             2.999         7.990                 62%     4.1          154
# 736             1.149         1.699                 32%     4.2     1,22,478
# 397             1.149         3.999                 71%     4.3     1,40,036
#
#          product type
# 584            In-Ear
# 459  ScreenProtectors
# 462      SmartWatches
# 736           Routers
# 397           MicroSD

# %%
df.rating_count = df.rating_count.str.split(".").str.get(0) +"."+ df.rating_count.str.split(".").str.get(1).fillna("0")

# %%
df['rating_count'] = df['rating_count'].apply(lambda x: x.replace(",", ".") if isinstance(x, str) else x)

# %%
df.rating_count = df.rating_count.astype(float)

# %%
df.dtypes
# Out:
# product_name            object
# category                object
# discounted_price       float64
# actual_price           float64
# discount_percentage     object
# rating                 float64
# rating_count           float64
# product type            object
# dtype: object

# %%
df['mean_of_ratings'] = pd.cut(df['rating'], [1,2,4,5], labels = ['Poor','Average','Good'])

# %%
df.sample(5)
# Out:
#                                            product_name  \
# 1011           HP v222w 64GB USB 2.0 Pen Drive (Silver)
# 658   boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 1373  IONIX Activated Carbon Faucet Water Filters Un...
# 116   Electvision Remote Control Compatible with Ama...
# 912   boAt Bassheads 102 Wired in Ear Earphones with...
#
#                    category  discounted_price  actual_price  \
# 1011  Computers&Accessories           449.000         1.300
# 658   Computers&Accessories           176.630       499.000
# 1373           Home&Kitchen           185.000       599.000
# 116             Electronics             1.299         1.999
# 912             Electronics           399.000         1.290
#
#      discount_percentage  rating  rating_count              product type  \
# 1011                 65%     4.2         4.959                 PenDrives
# 658                  65%     4.1        15.189                 USBCables
# 1373                 69%     3.9         1.306  WaterPurifierAccessories
# 116                  35%     3.6       590.000            RemoteControls
# 912                  69%     4.2        76.042                    In-Ear
#
#      mean_of_ratings
# 1011            Good
# 658             Good
# 1373         Average
# 116          Average
# 912             Good

# %%
df.dropna()
# Out:
#                                            product_name  \
# 0     Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     Sounce Fast Phone Charging Cable & Data Sync U...
# 3     boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...                                                 ...
# 1460  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                    category  discounted_price  actual_price  \
# 0     Computers&Accessories           399.000         1.099
# 1     Computers&Accessories           199.000       349.000
# 2     Computers&Accessories           199.000         1.899
# 3     Computers&Accessories           329.000       699.000
# 4     Computers&Accessories           154.000       399.000
# ...                     ...               ...           ...
# 1460           Home&Kitchen           379.000       919.000
# 1461           Home&Kitchen             2.280         3.045
# 1462           Home&Kitchen             2.219         3.080
# 1463           Home&Kitchen             1.399         1.890
# 1464           Home&Kitchen             2.863         3.690
#
#      discount_percentage  rating  rating_count              product type  \
# 0                    64%     4.2        24.269                 USBCables
# 1                    43%     4.0        43.994                 USBCables
# 2                    90%     3.9         7.928                 USBCables
# 3                    53%     4.2        94.363                 USBCables
# 4                    61%     4.2        16.905                 USBCables
# ...                  ...     ...           ...                       ...
# 1460                 59%     4.0         1.090  WaterPurifierAccessories
# 1461                 25%     4.1         4.118         Rice&PastaCookers
# 1462                 28%     3.6       468.000            HeatConvectors
# 1463                 26%     4.0         8.031               ExhaustFans
# 1464                 22%     4.3         6.987            SandwichMakers
#
#      mean_of_ratings
# 0               Good
# 1            Average
# 2            Average
# 3               Good
# 4               Good
# ...              ...
# 1460         Average
# 1461            Good
# 1462         Average
# 1463         Average
# 1464            Good
#
# [1462 rows x 9 columns]

# %%
df.isnull().mean()*100
# Out:
# product_name           0.000000
# category               0.000000
# discounted_price       0.000000
# actual_price           0.000000
# discount_percentage    0.000000
# rating                 0.068259
# rating_count           0.136519
# product type           0.000000
# mean_of_ratings        0.068259
# dtype: float64

# %%
df = df.dropna()

# %%
df.isnull().mean()*100
# Out:
# product_name           0.0
# category               0.0
# discounted_price       0.0
# actual_price           0.0
# discount_percentage    0.0
# rating                 0.0
# rating_count           0.0
# product type           0.0
# mean_of_ratings        0.0
# dtype: float64

# %%
df.category.nunique()
# Out:
# 9

# %%
df.rating.mean()
# Out:
# 4.096716826265389

# %%
plt.figure(figsize=(7,5))
ax = sns.countplot(data=df, x='category' ,palette = "tab10")
plt.title('Number of Products per Category')
plt.xlabel('Category')
plt.ylabel('Product Count')
plt.xticks(rotation=90)  
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 9), 
                textcoords = 'offset points')

plt.show()
# Out:
# C:\Users\riasa\AppData\Local\Temp\ipykernel_12652\3493899100.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x='category' ,palette = "tab10")

# %%
sns.pairplot(df)

# %%
sns.scatterplot(x='rating',y='discounted_price', data= df, color = "green")
plt.title("discounted_price & rating")
plt.show()

# %%
product_count=df.groupby('mean_of_ratings').size().reset_index(name='count')
# Out:
# C:\Users\riasa\AppData\Local\Temp\ipykernel_12652\410827884.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   product_count=df.groupby('mean_of_ratings').size().reset_index(name='count')

# %%
product_count
# Out:
#   mean_of_ratings  count
# 0            Poor      1
# 1         Average    533
# 2            Good    928

# %%
sns.countplot(x='mean_of_ratings', data=df, palette = "tab10")
plt.title("ratings Distribution")
for index, value in enumerate(product_count['count']):
    plt.text(index, value + 2, str(value), ha='center')
plt.show()
# Out:
# C:\Users\riasa\AppData\Local\Temp\ipykernel_12652\1205893870.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='mean_of_ratings', data=df, palette = "tab10")

# %%
sns.displot(x='rating',data=df,kde=True)

# %%
most_sold = df['product type'].value_counts().sort_values(ascending=False)[0:10]
most_sold
# Out:
# product type
# USBCables           231
# SmartWatches         76
# Smartphones          68
# SmartTelevisions     63
# In-Ear               52
# RemoteControls       49
# MixerGrinders        27
# HDMICables           24
# DryIrons             24
# Mice                 24
# Name: count, dtype: int64

# %%
colors = ['red', 'green', 'blue', 'purple', 'orange']

most_sold.plot(kind='bar',color=colors)
# Out:
# <Axes: xlabel='product type'>

# %%
c=df.groupby('product type')['discounted_price'].mean().reset_index(name='mean_of_dprice')
c
# Out:
#                product type  mean_of_dprice
# 0                 3DGlasses        2.699000
# 1    AVReceivers&Amplifiers        1.990000
# 2                  Adapters      149.666667
# 3    Adapters&Multi-Outlets      425.000000
# 4                 AirFryers        6.276400
# ..                      ...             ...
# 202             WetGrinders        3.683500
# 203      WireboundNotebooks      141.250000
# 204     WirelessUSBAdapters      356.088611
# 205           WoodenPencils       99.000000
# 206            YogurtMakers      587.000000
#
# [207 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize=(4, 6))
ax.pie(most_sold.values, labels=most_sold.index, autopct='%1.1f%%', startangle=90,
       shadow = True, textprops={'fontsize': 8},)


ax.set_title('Number of most sold 10 product', fontsize=10, fontweight='bold')
ax.axis('equal')

plt.show()

# %%
rating_count = df.groupby('rating')['rating'].count().reset_index(name="count")
rating_count.head()
# Out:
#    rating  count
# 0     2.0      1
# 1     2.3      1
# 2     2.6      1
# 3     2.8      2
# 4     2.9      1

# %%
sns.lineplot(data=rating_count, x='rating', y='count', marker='o',color = "red")
plt.title('total order & rating')
# Out:
# Text(0.5, 1.0, 'total order & rating')

# %%
sns.lineplot(data=df, x='rating', y='rating_count', marker='o', color="blue")
plt.title('Rating & Rating_Count')
plt.xlabel('Rating')
plt.ylabel('rating_Count')
plt.show()

# %%
df.to_csv('amazon-clean-data.csv', index=False)
